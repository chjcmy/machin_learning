# %%
#import the necessary packages
import folium
import pandas as pd

# importing the dataset as a csv file,
# and storing it as a dataframe in 'df'
df=pd.read_csv('Volcanoes_USA.txt')

# calculating the mean of the latitudes
# and longitudes of the locations of volcanoes
latmean=df['LAT'].mean()
lonmean=df['LON'].mean()

# Creating a map object using Map() function.
# Location parameter takes latitudes and
# longitudes as starting location.
# (Map will be centered at those co-ordinates)
map5 = folium.Map(location=[latmean,lonmean],
        zoom_start=6)

# Function to change the marker color
# according to the elevation of volcano
def color(elev):
    if elev in range(0,1000):
        col = 'green'
    elif elev in range(1001,1999):
        col = 'blue'
    elif elev in range(2000,2999):
        col = 'orange'
    else:
        col='red'
    return col

# Iterating over the LAT,LON,NAME and
# ELEV columns simultaneously using zip()
for lat,lan,name,elev in zip(df['LAT'],df['LON'],df['NAME'],df['ELEV']):
    # Marker() takes location coordinates
    # as a list as an argument
    folium.Marker(location=[lat,lan],popup = name,
                  icon= folium.Icon(color=color(elev),
                  icon_color='yellow',icon = 'cloud')).add_to(map5)

# Save the file created above
print(map5.save('Volcanoes_USA.html'))
# Out:
# None

# %%
map5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8def8053ad39e38bb244aebcc869b2cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8def8053ad39e38bb244aebcc869b2cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8def8053ad39e38bb244aebcc869b2cf = L.map(
#                 &quot;map_8def8053ad39e38bb244aebcc869b2cf&quot;,
#                 {
#                     center: [41.3125677983871, -118.2669679016129],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c555409c19699629a643f14c9201cffe = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c555409c19699629a643f14c9201cffe.addTo(map_8def8053ad39e38bb244aebcc869b2cf);
#
#
#             var marker_490c705544f5be29f3d97cda98cbcd92 = L.marker(
#                 [48.7767982, -121.810997],
#                 {
# }
#             ).addTo(map_8def8053ad39e38bb244aebcc869b2cf);
#
#
#             var icon_5cf1d8a4ae7d34eaec2acef170a89c6a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;yellow&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_052efd4a35044c6ee54208e1e331451b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e9456ca5f386ca2e65a3068e61ea002 = $(`&lt;div id=&quot;html_9e9456ca5f386ca2e65a3068e61ea002&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Baker&lt;/div&gt;`)[0];
#                 popup_052efd4a35044c6ee54208e1e331451b.setContent(html_9e9456ca5f386ca2e65a3068e61ea002);
#
#
#
#         marker_490c705544f5be29f3d97cda98cbcd92.bindPopup(popup_052efd4a35044c6ee54208e1e331451b)
#         ;
#
#
#
#
#                 marker_490c705544f5be29f3d97cda98cbcd92.setIcon(icon_5cf1d8a4ae7d34eaec2acef170a89c6a);
#
#
#             var marker_f9a0b008dbc80e2b7de6a7e9727f992c = L.marker(
#                 [48.1118011, -121.1110001],
#                 {
# }
#             ).addTo(map_8def8053ad39e38bb244aebcc869b2cf);
#
#
#             var icon_f45ca10e432837aadf8cbd9f19d78d6f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;yellow&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_daae828088d24356a819eedf359703b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b1340773136a257527c9358e15295ff = $(`&lt;div id=&quot;html_1b1340773136a257527c9358e15295ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Glacier Peak&lt;/div&gt;`)[0];
#                 popup_daae828088d24356a819eedf359703b1.setContent(html_1b1340773136a257527c9358e15295ff);
#
#
#
#         marker_f9a0b008dbc80e2b7de6a7e9727f992c.bindPopup(popup_daae828088d24356a819eedf359703b1)
#         ;
#
#
#
#
#                 marker_f9a0b008dbc80e2b7de6a7e9727f992c.setIcon(icon_f45ca10e432837aadf8cbd9f19d78d6f);
#
#
#             var marker_2fb7d2e49794c10b4c6574aa5ec4eafd = L.marker(
#                 [46.8698006, -121.7509995],
#                 {
# }
#             ).addTo(map_8def8053ad39e38bb244aebcc869b2cf);
#
#
#             var icon_c9b0618d157222c4839cda212508f853 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;yellow&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_622f8525efb48d8261ccf48e2c6330f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f1f4d8a201cfb8df2fa978549111356e = $(`&lt;div id=&quot;html_f1f4d8a201cfb8df2fa978549111356e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Rainier&lt;/div&gt;`)[0];
#                 popup_622f8525efb48d8261ccf48e2c6330f1.setContent(html_f1f4d8a201cfb8df2fa978549111356e);
#
#
#
#         marker_2fb7d2e49794c10b4c6574aa5ec4eafd.bindPopup(popup_622f8525efb48d8261ccf48e2c6330f1)
#         ;
#
#
#
#
#                 marker_2fb7d2e49794c10b4c6574aa5ec4eafd.setIcon(icon_c9b0618d157222c4839cda212508f853);
#
#
#             var marker_08f974b5e7426318bf9f95
